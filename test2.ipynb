# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.38.0 to work with xcuongbatch34

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Overwriting diabetes_pipeline/prep_diabetes.py

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-folder", type=str, dest='training_folder', help='training data folder')
args = parser.parse_args()
training_folder = args.training_folder

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_folder,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Overwriting diabetes_pipeline/train_diabetes.py

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "dp100-cluster"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment 
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.
# Run configuration created.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData("prepped_data_folder", datastore=ws.get_default_datastore())

# Step 1, Run the data prep script
train_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data_folder],
                                outputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
register_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-folder', prepped_data_folder],
                                inputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [06b0cd8b][4418448b-32f1-439c-a71e-0f826699cb00], (This step will run and generate new outputs)
# Created step Train and Register Model [3fcaba2a][4fb1701d-8b0f-43ac-a350-81e47c6f5e34], (This step will run and generate new outputs)
# Submitted PipelineRun 15ab9142-7098-4c43-93f7-274ef60b29a1
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/15ab9142-7098-4c43-93f7-274ef60b29a1?wsid=/subscriptions/09b3bdbf-5f62-40eb-8cdc-3e3652cd7c78/resourcegroups/new_resourcegroup/workspaces/xcuongbatch34&tid=3324bb2d-9b60-42f9-a25b-5913ffea01fe
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 15ab9142-7098-4c43-93f7-274ef60b29a1
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/15ab9142-7098-4c43-93f7-274ef60b29a1?wsid=/subscriptions/09b3bdbf-5f62-40eb-8cdc-3e3652cd7c78/resourcegroups/new_resourcegroup/workspaces/xcuongbatch34&tid=3324bb2d-9b60-42f9-a25b-5913ffea01fe
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 36e7bd56-f4a8-4d61-83da-92c5647877b0
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/36e7bd56-f4a8-4d61-83da-92c5647877b0?wsid=/subscriptions/09b3bdbf-5f62-40eb-8cdc-3e3652cd7c78/resourcegroups/new_resourcegroup/workspaces/xcuongbatch34&tid=3324bb2d-9b60-42f9-a25b-5913ffea01fe
# StepRun( Prepare Data ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/02/18 13:33:48 Downloading source code...
# 2022/02/18 13:33:49 Finished downloading source code
# 2022/02/18 13:33:49 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/02/18 13:33:49 Successfully set up Docker network: acb_default_network
# 2022/02/18 13:33:49 Setting up Docker configuration...
# 2022/02/18 13:33:50 Successfully set up Docker configuration
# 2022/02/18 13:33:50 Logging in to registry: 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io
# 2022/02/18 13:33:52 Successfully logged into 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io
# 2022/02/18 13:33:52 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/02/18 13:33:52 Scanning for dependencies...
# 2022/02/18 13:33:52 Successfully scanned dependencies
# 2022/02/18 13:33:52 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220113.v1@sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220113.v1@sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 2f94e549220a: Already exists
# 2b2d92136c10: Pulling fs layer
# 0b412d2669ed: Pulling fs layer
# 805003cfcee6: Pulling fs layer
# ad877dc53455: Pulling fs layer
# afa783568628: Pulling fs layer
# d67cf86adb17: Pulling fs layer
# 82770c3b2808: Pulling fs layer
# c991e53ceb53: Pulling fs layer
# ad877dc53455: Waiting
# afa783568628: Waiting
# d67cf86adb17: Waiting
# 82770c3b2808: Waiting
# c991e53ceb53: Waiting
# 0b412d2669ed: Verifying Checksum
# 0b412d2669ed: Download complete
# 2b2d92136c10: Verifying Checksum
# 2b2d92136c10: Download complete
# ad877dc53455: Verifying Checksum
# ad877dc53455: Download complete
# afa783568628: Verifying Checksum
# afa783568628: Download complete
# 82770c3b2808: Verifying Checksum
# 82770c3b2808: Download complete
# 805003cfcee6: Verifying Checksum
# 805003cfcee6: Download complete
# d67cf86adb17: Verifying Checksum
# d67cf86adb17: Download complete
# c991e53ceb53: Verifying Checksum
# c991e53ceb53: Download complete
# 2b2d92136c10: Pull complete
# 0b412d2669ed: Pull complete
# 805003cfcee6: Pull complete
# ad877dc53455: Pull complete
# afa783568628: Pull complete
# d67cf86adb17: Pull complete
# 82770c3b2808: Pull complete
# c991e53ceb53: Pull complete
# Digest: sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220113.v1@sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
#  ---> 54296612fc48
# Step 2/21 : USER root
#  ---> Running in 951d1036af56
# Removing intermediate container 951d1036af56
#  ---> 541c6561b89f
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in 4e76bfc0bac0
# Removing intermediate container 4e76bfc0bac0
#  ---> de53bb58b5f8
# Step 4/21 : WORKDIR /
#  ---> Running in 3e35a64bfd2e
# Removing intermediate container 3e35a64bfd2e
#  ---> ca34d5ba9e8c
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> a62e972b6006
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 09c062ba9f6f
# Removing intermediate container 09c062ba9f6f
#  ---> 5782b9d0de65
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 375eac2a16b2
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 38ded67ff38a
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ##5        |  25%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
# pillow-8.0.0         | 675 KB    | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | #########6 |  97%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | #######3   |  73%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | ########   |  80%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | #1         |  11%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ######3    |  64%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ###6       |  36%
# scikit-learn-0.23.2  | 6.9 MB    | #####8     |  58%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ########3  |  83%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  |            |   1%
# mkl-2019.4           | 204.1 MB  | 2          |   3%
# mkl-2019.4           | 204.1 MB  | 4          |   5%
# mkl-2019.4           | 204.1 MB  | 6          |   7%
# mkl-2019.4           | 204.1 MB  | 8          |   8%
# mkl-2019.4           | 204.1 MB  | #1         |  11%
# mkl-2019.4           | 204.1 MB  | #3         |  14%
# mkl-2019.4           | 204.1 MB  | #6         |  16%
# mkl-2019.4           | 204.1 MB  | #9         |  19%
# mkl-2019.4           | 204.1 MB  | ##1        |  22%
# mkl-2019.4           | 204.1 MB  | ##4        |  24%
# mkl-2019.4           | 204.1 MB  | ##7        |  27%
# mkl-2019.4           | 204.1 MB  | ##9        |  30%
# mkl-2019.4           | 204.1 MB  | ###2       |  33%
# mkl-2019.4           | 204.1 MB  | ###5       |  35%
# mkl-2019.4           | 204.1 MB  | ###7       |  38%
# mkl-2019.4           | 204.1 MB  | ####1      |  41%
# mkl-2019.4           | 204.1 MB  | ####4      |  44%
# mkl-2019.4           | 204.1 MB  | ####7      |  47%
# mkl-2019.4           | 204.1 MB  | ####9      |  50%
# mkl-2019.4           | 204.1 MB  | #####2     |  52%
# mkl-2019.4           | 204.1 MB  | #####5     |  55%
# mkl-2019.4           | 204.1 MB  | #####7     |  57%
# mkl-2019.4           | 204.1 MB  | ######     |  60%
# mkl-2019.4           | 204.1 MB  | ######3    |  63%
# mkl-2019.4           | 204.1 MB  | ######5    |  66%
# mkl-2019.4           | 204.1 MB  | ######8    |  68%
# mkl-2019.4           | 204.1 MB  | #######    |  71%
# mkl-2019.4           | 204.1 MB  | #######3   |  73%
# mkl-2019.4           | 204.1 MB  | #######5   |  76%
# mkl-2019.4           | 204.1 MB  | ########   |  80%
# mkl-2019.4           | 204.1 MB  | ########3  |  83%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | 6          |   7%
# scipy-1.5.2          | 18.5 MB   | #          |  11%
# scipy-1.5.2          | 18.5 MB   | ##7        |  27%
# scipy-1.5.2          | 18.5 MB   | ######     |  61%
# scipy-1.5.2          | 18.5 MB   | #######4   |  75%
# scipy-1.5.2          | 18.5 MB   | #########2 |  92%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | ########## | 100%
# jedi-0.17.2          | 952 KB    | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##3        |  23%
# python-3.6.2         | 27.0 MB   | #####8     |  59%
# python-3.6.2         | 27.0 MB   | #######4   |  74%
# python-3.6.2         | 27.0 MB   | ########9  |  90%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ######7    |  67%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 9          |  10%
# qt-5.9.6             | 86.7 MB   | ##4        |  24%
# qt-5.9.6             | 86.7 MB   | ###8       |  38%
# qt-5.9.6             | 86.7 MB   | #####      |  51%
# qt-5.9.6             | 86.7 MB   | ######2    |  63%
# qt-5.9.6             | 86.7 MB   | #######5   |  75%
# qt-5.9.6             | 86.7 MB   | ########6  |  87%
# qt-5.9.6             | 86.7 MB   | #########8 |  98%
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | #4         |  14%
# icu-58.2             | 22.7 MB   | ###8       |  39%
# icu-58.2             | 22.7 MB   | ######2    |  63%
# icu-58.2             | 22.7 MB   | #######8   |  78%
# icu-58.2             | 22.7 MB   | ########## | 100%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.g8js9ut3.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.38.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.27.1-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
# Collecting azureml-dataset-runtime[fuse]~=1.38.0
#   Downloading azureml_dataset_runtime-1.38.0-py3-none-any.whl (3.5 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-core~=1.38.0
#   Downloading azureml_core-1.38.0.post2-py3-none-any.whl (2.5 MB)
# Collecting azureml-inference-server-http~=0.4.1
#   Downloading azureml_inference_server_http-0.4.2-py3-none-any.whl (38 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting azureml-dataprep-rslex~=2.3.0dev0
#   Downloading azureml_dataprep_rslex-2.3.1-cp36-cp36m-manylinux1_x86_64.whl (13.6 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.23-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.g8js9ut3.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.g8js9ut3.requirements.txt (line 2)) (1.1.3)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azure-mgmt-resource<21.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-20.1.0-py3-none-any.whl (2.3 MB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.1.0-py2.py3-none-any.whl (38 kB)
# Collecting azure-core<1.22
#   Downloading azure_core-1.21.1-py2.py3-none-any.whl (178 kB)
# Collecting azure-mgmt-storage<20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-19.1.0-py3-none-any.whl (1.8 MB)
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.8.2-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-core~=1.38.0->azureml-defaults->-r /azureml-environment-setup/condaenv.g8js9ut3.requirements.txt (line 1)) (2020.1)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting argcomplete<2.0
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting pyopenssl<22.0.0
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting msal-extensions<0.4,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-core~=1.38.0->azureml-defaults->-r /azureml-environment-setup/condaenv.g8js9ut3.requirements.txt (line 1)) (2.8.1)
# Collecting knack~=0.8.2
#   Downloading knack-0.8.2-py3-none-any.whl (59 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
# Collecting azure-mgmt-containerregistry<9.0.0,>=8.2.0
#   Downloading azure_mgmt_containerregistry-8.2.0-py2.py3-none-any.whl (928 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.9.2-py2.py3-none-any.whl (210 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting urllib3<=1.26.7,>=1.23
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.17.0-py2.py3-none-any.whl (79 kB)
# Collecting gunicorn==20.1.0; platform_system != "Windows"
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting inference-schema==1.3.0
#   Downloading inference_schema-1.3.0-py3-none-any.whl (19 kB)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azure-identity==1.7.0->azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.g8js9ut3.requirements.txt (line 2)) (1.15.0)
# Collecting distro>=1.2.0
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.3.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.5,>=2.0.2 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from packaging<22.0,>=20.0->azureml-core~=1.38.0->azureml-defaults->-r /azureml-environment-setup/condaenv.g8js9ut3.requirements.txt (line 1)) (2.4.7)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.3-py3-none-any.whl (53 kB)
# Collecting portalocker<3,>=1.0; python_version >= "3.5" and platform_system != "Windows"
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied, skipping upgrade: pygments in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from knack~=0.8.2->azureml-core~=1.38.0->azureml-defaults->-r /azureml-environment-setup/condaenv.g8js9ut3.requirements.txt (line 1)) (2.7.1)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.38.0->azureml-defaults->-r /azureml-environment-setup/condaenv.g8js9ut3.requirements.txt (line 1)) (2020.6.20)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting PySocks!=1.5.7,>=1.5.6; extra == "socks"
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (61 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Requirement already satisfied, skipping upgrade: setuptools>=3.0 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from gunicorn==20.1.0; platform_system != "Windows"->azureml-inference-server-http~=0.4.1->azureml-defaults->-r /azureml-environment-setup/condaenv.g8js9ut3.requirements.txt (line 1)) (50.3.0.post20201006)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting click>=5.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Collecting Werkzeug>=0.14
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Collecting dataclasses; python_version < "3.7"
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=36c33c4770e5a2ff8746ddda59a9d4c3270fae1d8abed447fb21a28830a577da
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=9a78877335ed9042daec682c876a2ea8b763e8ac98cf0b5a7ad477d4b15d93b0
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69878 sha256=b3db9f8d77af1fc4e21f34d105e31cdf839da2a19134e9fad4956dd70520e73c
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
# Successfully built json-logging-py fusepy wrapt
# Installing collected packages: azureml-dataprep-native, idna, urllib3, charset-normalizer, PySocks, requests, pycparser, cffi, cryptography, PyJWT, msal, portalocker, msal-extensions, azure-core, azure-identity, cloudpickle, azureml-dataprep-rslex, distro, dotnetcore2, pyarrow, azureml-dataprep, fusepy, azureml-dataset-runtime, configparser, azure-mgmt-core, azure-common, isodate, oauthlib, requests-oauthlib, msrest, azure-mgmt-resource, adal, msrestazure, azure-mgmt-authorization, typing-extensions, zipp, importlib-metadata, jsonpickle, azure-mgmt-storage, packaging, contextlib2, pkginfo, jmespath, backports.weakref, backports.tempfile, argcomplete, pathspec, pyopenssl, websocket-client, docker, colorama, tabulate, pyyaml, knack, pyasn1, ndg-httpsclient, azure-mgmt-keyvault, azure-graphrbac, azure-mgmt-containerregistry, bcrypt, pynacl, paramiko, jeepney, SecretStorage, humanfriendly, azureml-core, gunicorn, applicationinsights, itsdangerous, MarkupSafe, Jinja2, click, dataclasses, Werkzeug, flask, wrapt, inference-schema, azureml-inference-server-http, json-logging-py, azureml-defaults
# Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.3.0 PySocks-1.7.1 SecretStorage-3.3.1 Werkzeug-2.0.3 adal-1.2.7 applicationinsights-0.11.10 argcomplete-1.12.3 azure-common-1.1.28 azure-core-1.21.1 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.2.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.3.0 azure-mgmt-resource-20.1.0 azure-mgmt-storage-19.1.0 azureml-core-1.38.0.post2 azureml-dataprep-2.27.1 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.3.1 azureml-dataset-runtime-1.38.0 azureml-defaults-1.38.0 azureml-inference-server-http-0.4.2 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.0 cffi-1.15.0 charset-normalizer-2.0.12 click-8.0.3 cloudpickle-2.0.0 colorama-0.4.4 configparser-3.7.4 contextlib2-21.6.0 cryptography-36.0.1 dataclasses-0.8 distro-1.7.0 docker-5.0.3 dotnetcore2-2.1.23 flask-1.0.3 fusepy-3.0.1 gunicorn-20.1.0 humanfriendly-10.0 idna-3.3 importlib-metadata-4.8.3 inference-schema-1.3.0 isodate-0.6.1 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.1.0 knack-0.8.2 msal-1.17.0 msal-extensions-0.3.1 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.0 packaging-21.3 paramiko-2.9.2 pathspec-0.9.0 pkginfo-1.8.2 portalocker-2.4.0 pyarrow-6.0.1 pyasn1-0.4.8 pycparser-2.21 pynacl-1.5.0 pyopenssl-21.0.0 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 tabulate-0.8.9 typing-extensions-4.1.1 urllib3-1.26.7 websocket-client-1.2.3 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 38ded67ff38a
#  ---> f63d64dc6087
# Step 9/21 : ENV PATH /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin:$PATH
#  ---> Running in ed2dea80a85b
# Removing intermediate container ed2dea80a85b
#  ---> f9d45e6caaf2
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> c8c9d8ccd405
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in d6a8c7a603a5
# Copying environment context
# Removing intermediate container d6a8c7a603a5
#  ---> 598f4f4be0fa
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> b70b07708fc0
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472
#  ---> Running in f6893969943a
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container f6893969943a
#  ---> 2039840ddf1f
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472
#  ---> Running in fcc397dcbc9f
# Removing intermediate container fcc397dcbc9f
#  ---> aa921370c1e3
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib:$LD_LIBRARY_PATH
#  ---> Running in 705081727a9d
# Removing intermediate container 705081727a9d
#  ---> dc42a89cf04f
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_37123770cfa02a1fe00f423fa57ee472 CONDA_PREFIX=/azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472
#  ---> Running in a82c506d3dc4
# Removing intermediate container a82c506d3dc4
#  ---> 9f72786d912e
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 118b3188773b
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 4b64d027489d
# Removing intermediate container 4b64d027489d
#  ---> a62d91aba983
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in 91e1d0f9de1f
# Removing intermediate container 91e1d0f9de1f
#  ---> 8226f556c8de
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in e7996f9011a6
# Removing intermediate container e7996f9011a6
#  ---> b8b5569eb857
# Step 21/21 : CMD ["bash"]
#  ---> Running in f78fea95657c
# Removing intermediate container f78fea95657c
#  ---> 0c0f5275843b
# Successfully built 0c0f5275843b
# Successfully tagged 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io/azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb:latest
# Successfully tagged 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io/azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb:1
# 2022/02/18 13:38:50 Successfully executed container: acb_step_0
# 2022/02/18 13:38:50 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/02/18 13:38:50 Pushing image: 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io/azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb:1, attempt 1
# The push refers to repository [10e4a2cc72a9476291ad66e99bd020f5.azurecr.io/azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb]
# eca22ad52bba: Preparing
# 3940b6f4f984: Preparing
# 688f83401090: Preparing
# e15e3efb298b: Preparing
# fe52399dd4ee: Preparing
# 48298b08d8cc: Preparing
# e5c3a6bcc26f: Preparing
# d5454a627337: Preparing
# feb3f9affe2d: Preparing
# 834a3ac05a75: Preparing
# 5a63f0a64b99: Preparing
# cfd97667b73b: Preparing
# dda643f89a6b: Preparing
# 06f4d263b25f: Preparing
# 5ecae586bbba: Preparing
# eb66e810a3df: Preparing
# 081c0f822cac: Preparing
# 0be4c2d28ad7: Preparing
# 40a154bd3352: Preparing
# 48298b08d8cc: Waiting
# e5c3a6bcc26f: Waiting
# d5454a627337: Waiting
# feb3f9affe2d: Waiting
# 834a3ac05a75: Waiting
# 5a63f0a64b99: Waiting
# cfd97667b73b: Waiting
# dda643f89a6b: Waiting
# 06f4d263b25f: Waiting
# 5ecae586bbba: Waiting
# eb66e810a3df: Waiting
# 081c0f822cac: Waiting
# 0be4c2d28ad7: Waiting
# 40a154bd3352: Waiting
# fe52399dd4ee: Pushed
# e15e3efb298b: Pushed
# 3940b6f4f984: Pushed
# eca22ad52bba: Pushed
# 688f83401090: Pushed
# d5454a627337: Pushed
# feb3f9affe2d: Pushed
# 834a3ac05a75: Pushed
# e5c3a6bcc26f: Pushed
# 5a63f0a64b99: Pushed
# cfd97667b73b: Pushed
# 06f4d263b25f: Pushed
# dda643f89a6b: Pushed
#
# 081c0f822cac: Pushed
# eb66e810a3df: Pushed
# 5ecae586bbba: Pushed
# 40a154bd3352: Pushed
# 0be4c2d28ad7: Pushed
# 48298b08d8cc: Pushed
# 1: digest: sha256:896d2b2769e595f5968189d53750efd9095055697d9733388e13761d02b6da93 size: 4307
# 2022/02/18 13:40:48 Successfully pushed image: 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io/azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb:1
# 2022/02/18 13:40:48 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/02/18 13:40:48 Pushing image: 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io/azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb:latest, attempt 1
# The push refers to repository [10e4a2cc72a9476291ad66e99bd020f5.azurecr.io/azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb]
# eca22ad52bba: Preparing
# 3940b6f4f984: Preparing
# 688f83401090: Preparing
# e15e3efb298b: Preparing
# fe52399dd4ee: Preparing
# 48298b08d8cc: Preparing
# e5c3a6bcc26f: Preparing
# d5454a627337: Preparing
# feb3f9affe2d: Preparing
# 834a3ac05a75: Preparing
# 5a63f0a64b99: Preparing
# cfd97667b73b: Preparing
# dda643f89a6b: Preparing
# 06f4d263b25f: Preparing
# 5ecae586bbba: Preparing
# eb66e810a3df: Preparing
# 081c0f822cac: Preparing
# 0be4c2d28ad7: Preparing
# 40a154bd3352: Preparing
# 48298b08d8cc: Waiting
# e5c3a6bcc26f: Waiting
# d5454a627337: Waiting
# feb3f9affe2d: Waiting
# 834a3ac05a75: Waiting
# 5a63f0a64b99: Waiting
# cfd97667b73b: Waiting
# dda643f89a6b: Waiting
# 06f4d263b25f: Waiting
# 5ecae586bbba: Waiting
# eb66e810a3df: Waiting
# 081c0f822cac: Waiting
# 0be4c2d28ad7: Waiting
# 40a154bd3352: Waiting
# eca22ad52bba: Layer already exists
# 3940b6f4f984: Layer already exists
# 48298b08d8cc: Layer already exists
# e5c3a6bcc26f: Layer already exists
# d5454a627337: Layer already exists
# feb3f9affe2d: Layer already exists
# 5a63f0a64b99: Layer already exists
# 834a3ac05a75: Layer already exists
# cfd97667b73b: Layer already exists
# e15e3efb298b: Layer already exists
# 688f83401090: Layer already exists
# fe52399dd4ee: Layer already exists
# 06f4d263b25f: Layer already exists
# dda643f89a6b: Layer already exists
# 5ecae586bbba: Layer already exists
# 081c0f822cac: Layer already exists
# eb66e810a3df: Layer already exists
# 40a154bd3352: Layer already exists
# 0be4c2d28ad7: Layer already exists
# latest: digest: sha256:896d2b2769e595f5968189d53750efd9095055697d9733388e13761d02b6da93 size: 4307
# 2022/02/18 13:40:54 Successfully pushed image: 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io/azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb:latest
# 2022/02/18 13:40:54 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 298.366922)
# 2022/02/18 13:40:54 Populating digests for step ID: acb_step_0...
# 2022/02/18 13:40:56 Successfully populated digests for step ID: acb_step_0
# 2022/02/18 13:40:56 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 117.930070)
# 2022/02/18 13:40:56 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 6.648476)
# 2022/02/18 13:40:56 The following dependencies were found:
# 2022/02/18 13:40:56
# - image:
#     registry: 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io
#     repository: azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb
#     tag: latest
#     digest: sha256:896d2b2769e595f5968189d53750efd9095055697d9733388e13761d02b6da93
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20220113.v1
#     digest: sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
#   git: {}
# - image:
#     registry: 10e4a2cc72a9476291ad66e99bd020f5.azurecr.io
#     repository: azureml/azureml_d360ee1ae11ef7ab69c130bc82c46cbb
#     tag: "1"
#     digest: sha256:896d2b2769e595f5968189d53750efd9095055697d9733388e13761d02b6da93
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20220113.v1
#     digest: sha256:024c1f016bc4fe902601239d41f526ea987816ba25b524c22c4cb3cdd8db6ebf
#   git: {}
#
#
# Run ID: chm was successful after 7m9s
#
# StepRun(Prepare Data) Execution Summary
# ========================================
# StepRun( Prepare Data ) Status: Finished
# {'runId': '36e7bd56-f4a8-4d61-83da-92c5647877b0', 'target': 'dp100-cluster', 'status': 'Completed', 'startTimeUtc': '2022-02-18T13:41:11.643894Z', 'endTimeUtc': '2022-02-18T13:42:12.507947Z', 'services': {}, 'properties': {'ContentSnapshotId': '82a8885e-ff8c-4b11-9de3-58bb15c82671', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '4418448b-32f1-439c-a71e-0f826699cb00', 'azureml.moduleName': 'Prepare Data', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '06b0cd8b', 'azureml.pipelinerunid': '15ab9142-7098-4c43-93f7-274ef60b29a1', 'azureml.pipeline': '15ab9142-7098-4c43-93f7-274ef60b29a1', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '37548b68-3384-4876-8e17-f2568f5ea75c'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'prep_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--input-data', 'DatasetConsumptionConfig:raw_data', '--prepped-data', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'dp100-cluster', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/36e7bd56-f4a8-4d61-83da-92c5647877b0/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': '37548b68-3384-4876-8e17-f2568f5ea75c', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_37123770cfa02a1fe00f423fa57ee472'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220113.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'ya ...
#
#
#
#
# StepRunId: 355baa5d-d314-41f1-b404-2303d9419763
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/355baa5d-d314-41f1-b404-2303d9419763?wsid=/subscriptions/09b3bdbf-5f62-40eb-8cdc-3e3652cd7c78/resourcegroups/new_resourcegroup/workspaces/xcuongbatch34&tid=3324bb2d-9b60-42f9-a25b-5913ffea01fe
# StepRun( Train and Register Model ) Status: NotStarted
# StepRun( Train and Register Model ) Status: Running
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': '355baa5d-d314-41f1-b404-2303d9419763', 'target': 'dp100-cluster', 'status': 'Completed', 'startTimeUtc': '2022-02-18T13:42:38.114357Z', 'endTimeUtc': '2022-02-18T13:42:44.400054Z', 'services': {}, 'properties': {'ContentSnapshotId': '82a8885e-ff8c-4b11-9de3-58bb15c82671', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '4fb1701d-8b0f-43ac-a350-81e47c6f5e34', 'azureml.moduleName': 'Train and Register Model', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '3fcaba2a', 'azureml.pipelinerunid': '15ab9142-7098-4c43-93f7-274ef60b29a1', 'azureml.pipeline': '15ab9142-7098-4c43-93f7-274ef60b29a1', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-folder', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'dp100-cluster', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/36e7bd56-f4a8-4d61-83da-92c5647877b0/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_37123770cfa02a1fe00f423fa57ee472'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20220113.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': []}, 'logFiles': {'logs/azureml/executionlogs.txt': 'https:/ ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '15ab9142-7098-4c43-93f7-274ef60b29a1', 'status': 'Completed', 'startTimeUtc': '2022-02-18T13:33:41.097099Z', 'endTimeUtc': '2022-02-18T13:42:46.60637Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://xcuongbatch349302342871.blob.core.windows.net/azureml/ExperimentRun/dcid.15ab9142-7098-4c43-93f7-274ef60b29a1/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=53hm5iVMoN3p6HaUL1MsiY59cASXwjMzDh1Z5BLdrco%3D&skoid=37fa96a2-7eb5-4dc7-b5cb-3691270e2fe6&sktid=3324bb2d-9b60-42f9-a25b-5913ffea01fe&skt=2022-02-18T13%3A15%3A11Z&ske=2022-02-19T21%3A25%3A11Z&sks=b&skv=2019-07-07&st=2022-02-18T13%3A29%3A22Z&se=2022-02-18T21%3A39%3A22Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://xcuongbatch349302342871.blob.core.windows.net/azureml/ExperimentRun/dcid.15ab9142-7098-4c43-93f7-274ef60b29a1/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=Jxu9E1UgtXJhmndRhLYvO124pvfEpXefuYc6ZebdQWc%3D&skoid=37fa96a2-7eb5-4dc7-b5cb-3691270e2fe6&sktid=3324bb2d-9b60-42f9-a25b-5913ffea01fe&skt=2022-02-18T13%3A15%3A11Z&ske=2022-02-19T21%3A25%3A11Z&sks=b&skv=2019-07-07&st=2022-02-18T13%3A29%3A22Z&se=2022-02-18T21%3A39%3A22Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://xcuongbatch349302342871.blob.core.windows.net/azureml/ExperimentRun/dcid.15ab9142-7098-4c43-93f7-274ef60b29a1/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=O78U7OZKo1P%2FNCNXC3QfRbRfbP4a6%2Bhl2iOKygnub9A%3D&skoid=37fa96a2-7eb5-4dc7-b5cb-3691270e2fe6&sktid=3324bb2d-9b60-42f9-a25b-5913ffea01fe&skt=2022-02-18T13%3A15%3A11Z&ske=2022-02-19T21%3A25%3A11Z&sks=b&skv=2019-07-07&st=2022-02-18T13%3A29%3A22Z&se=2022-02-18T21%3A39%3A22Z&sp=r'}, 'submittedBy': 'user5 user5'}
# 'Finished'

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.8966666666666666
# 	 AUC : 0.882087124325673
# 	 ROC : aml://artifactId/ExperimentRun/dcid.355baa5d-d314-41f1-b404-2303d9419763/ROC_1645191754.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 3
# 	 Training context : Pipeline
# 	 AUC : 0.882087124325673
# 	 Accuracy : 0.8966666666666666
#
#
# diabetes_model version: 2
# 	 Training context : Pipeline
# 	 AUC : 0.8826080493646704
# 	 Accuracy : 0.8982222222222223
#
#
# diabetes_model version: 1
# 	 Training context : Pipeline
# 	 AUC : 0.8845988456920495
# 	 Accuracy : 0.9
#
#
# testing version: 8
#
#
# testing version: 7
#
#
# testing version: 6
#
#
# testing version: 5
#
#
# testing version: 4
#
#
# testing version: 3
#
#
# testing version: 2
#
#
# testing version: 1
#
#
# test version: 3
#
#
# test version: 2
#
#
# test version: 1
#
#
# 1 version: 2
#
#
# 1 version: 1
#
#
# c version: 2
#
#
# c version: 1
#
#
# weather_forecast version: 14
#
#
# weather_forecast version: 13
#
#
# weather_forecast version: 12
#
#
# weather_forecast version: 11
#
#
# weather_forecast version: 10
#
#
# weather_forecast version: 9
#
#
# weather_forecast version: 8
#
#
# weather_forecast version: 7
#
#
# weather_forecast version: 6
#
#
# weather_forecast version: 5
#
#
# weather_forecast version: 4
#
#
# weather_forecast version: 3
#
#
# weather_forecast version: 2
#
#
# weather_forecast version: 1
#
#
# LSTMver1 version: 17
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 16
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 15
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 14
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 13
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 12
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 11
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 10
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 9
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 8
# 	 area : temp
# 	 type : forecast
#
#
# AutoML41d11438130 version: 1
#
#
# LSTMver1 version: 7
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 6
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 5
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 4
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 3
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 2
# 	 area : temp
# 	 type : forecast
#
#
# LSTMver1 version: 1
# 	 area : temp
# 	 type : forecast
#
#
# my-sklearn-model version: 1
# 	 area : diabetes
# 	 type : regression
#
#
# LSTM version: 2
#
#
# LSTM version: 1
